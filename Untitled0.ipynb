# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAli1995/EEEnthusiast/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-a056a36e3449> in <module>()
# ----> 1 import urllib2
#       2
#       3 url = "https://storage.cloud.google.com/avspeech-files/avspeech_train.csv"
#       4 filedata = urllib2.urlopen(url)
#       5 datatowrite = filedata.read()
#
# ModuleNotFoundError: No module named 'urllib2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
